# %%
#Import all the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the first dataset
path = r'D:\Next Hikes\Project 1\dataset_1.xlsx'
data_set_1 = pd.read_excel(path)

# %%
data_set_1.shape
# Out:
# (610, 10)

# %%
#Load the second dataset
path = r'D:\Next Hikes\Project 1\dataset_2.xlsx'
data_set_2 = pd.read_excel(path)

# %%
data_set_2.shape
# Out:
# (610, 8)

# %%
data_set_2 = data_set_2.drop(['Unnamed: 0'], axis = 1)

# %%
data_set_2.head(5)
# Out:
#    instant   atemp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81        0.0       3          13   16
# 1        2  0.2727  0.80        0.0       8          32   40
# 2        3  0.2727  0.80        0.0       5          27   32
# 3        4  0.2879  0.75        0.0       3          10   13
# 4        5  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Combining dataset1 and dataset2**

# %%
combined_dataset = pd.merge(data_set_1, data_set_2, on = 'instant', how = 'inner')

# %% [markdown]
# **dimensions of the dataset**

# %%
combined_dataset.shape
# Out:
# (610, 16)

# %%
combined_dataset.head(5)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1 2011-01-01       1   0     1   0    False        6           1
# 1        2 2011-01-01       1   0     1   1    False        6           1
# 2        3 2011-01-01       1   0     1   2    False        6           1
# 3        4 2011-01-01       1   0     1   3    False        6           1
# 4        5 2011-01-01       1   0     1   4    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Dropping unnecessary column**

# %%
combined_dataset = combined_dataset.drop(['yr'], axis = 1)

# %%
combined_dataset.head(5)
# Out:
#    instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1 2011-01-01       1     1   0    False        6           1  0.24
# 1        2 2011-01-01       1     1   1    False        6           1  0.22
# 2        3 2011-01-01       1     1   2    False        6           1  0.22
# 3        4 2011-01-01       1     1   3    False        6           1  0.24
# 4        5 2011-01-01       1     1   4    False        6           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt
# 0  0.2879  0.81        0.0       3          13   16
# 1  0.2727  0.80        0.0       8          32   40
# 2  0.2727  0.80        0.0       5          27   32
# 3  0.2879  0.75        0.0       3          10   13
# 4  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **datatype of the dataset**

# %%
combined_dataset.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %% [markdown]
# **Treat missing values**

# %%
combined_dataset.isnull()
# Out:
#      instant  dteday  season   mnth     hr  holiday  weekday  weathersit  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# ..       ...     ...     ...    ...    ...      ...      ...         ...
# 605    False   False   False  False  False    False    False       False
# 606    False   False   False  False  False    False    False       False
# 607    False   False   False  False  False    False    False       False
# 608    False   False   False  False  False    False    False       False
# 609    False   False   False  False  False    False    False       False
#
#       temp  atemp    hum  windspeed  casual  registered    cnt
# ...

# %%
combined_dataset = combined_dataset.fillna(value =0 )
combined_dataset
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28       1     1  11    False        5           3  0.18
# 606      607 2011-01-28       1     1  12    False        5           3  0.18
# 607      608 2011-01-28       1     1  13    False        5           3  0.18
# 608      609 2011-01-28       1     1  14    False        5           3  0.22
# 609      610 2011-01-28       1     1  15    False        5           2  0.20
#
# ...

# %% [markdown]
# **Identify Unique values**

# %%
value_counts_column1 = combined_dataset['weekday'].value_counts()
value_counts_column2 = combined_dataset['windspeed'].value_counts()

# Print the value counts
print("Value counts for Column1:\n", value_counts_column1)
print("Value counts for Column2:\n", value_counts_column2)
# Out:
# Value counts for Column1:
#  weekday
# 6    95
# 0    94
# 1    93
# 5    85
# 3    84
# 2    80
# 4    79
# Name: count, dtype: int64
# Value counts for Column2:
#  windspeed
# 0.1642    65
# 0.0000    62
# 0.1940    54
# 0.1343    54
# 0.1045    51
# 0.2537    49
# 0.2836    47
# 0.2239    45
# 0.0896    45
# 0.3284    34
# 0.2985    29
# 0.3881    18
# 0.3582    18
# 0.4478    11
# 0.4179    11
# 0.4627     8
# 0.5224     4
# 0.5821     3
# 0.4925     1
# 0.5522     1
# Name: count, dtype: int64

# %% [markdown]
# **central tendency**

# %%
combined_dataset['temp'].median()
# Out:
# 0.2

# %%
combined_dataset['windspeed'].mean()
# Out:
# 0.20485098360655737

# %%
combined_dataset['hum'].mode()
# Out:
# 0    0.47
# Name: hum, dtype: float64

# %%
path = r'D:\Next Hikes\Project 1\dataset_3.xlsx'
data_set_3 = pd.read_excel(path)

# %%
#Merge dataset 3 with combined dataset
final_data_set = pd.concat([combined_dataset,data_set_3])

# %%
final_data_set.shape
# Out:
# (1000, 16)

# %%
final_data_set.head(10)
# Out:
#    instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1 2011-01-01       1     1   0    False        6           1  0.24
# 1        2 2011-01-01       1     1   1    False        6           1  0.22
# 2        3 2011-01-01       1     1   2    False        6           1  0.22
# 3        4 2011-01-01       1     1   3    False        6           1  0.24
# 4        5 2011-01-01       1     1   4    False        6           1  0.24
# 5        6 2011-01-01       1     1   5    False        6           2  0.24
# 6        7 2011-01-01       1     1   6    False        6           1  0.22
# 7        8 2011-01-01       1     1   7    False        6           1  0.20
# 8        9 2011-01-01       1     1   8    False        6           1  0.24
# 9       10 2011-01-01       1     1   9    False        6           1  0.32
#
#     atemp   hum  windspeed  casual  registered  cnt  yr
# 0  0.2879  0.81     0.0000       3          13   16 NaN
# ...

# %%
final_data_set.rename(columns= {'atemp' :'temp'}, inplace=True)
data_set_2.head(10)
# Out:
#    instant    temp   hum  windspeed  casual  registered  cnt
# 0        1  0.2879  0.81     0.0000       3          13   16
# 1        2  0.2727  0.80     0.0000       8          32   40
# 2        3  0.2727  0.80     0.0000       5          27   32
# 3        4  0.2879  0.75     0.0000       3          10   13
# 4        5  0.2879  0.75     0.0000       0           1    1
# 5        6  0.2576  0.75     0.0896       0           1    1
# 6        7  0.2727  0.80     0.0000       2           0    2
# 7        8  0.2576  0.86     0.0000       1           2    3
# 8        9     NaN  0.75     0.0000       1           7    8
# 9       10  0.3485  0.76     0.0000       8           6   14

# %%
display(data_set_3.shape,combined_dataset.shape)
# Out:
# (390, 16)
# (610, 15)

# %%
final_data_set = pd.concat([combined_dataset,data_set_3])
final_data_set.shape
# Out:
# (1000, 16)

# %%
final_data_set.head(5)
# Out:
#    instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        1 2011-01-01       1     1   0    False        6           1  0.24
# 1        2 2011-01-01       1     1   1    False        6           1  0.22
# 2        3 2011-01-01       1     1   2    False        6           1  0.22
# 3        4 2011-01-01       1     1   3    False        6           1  0.24
# 4        5 2011-01-01       1     1   4    False        6           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt  yr
# 0  0.2879  0.81        0.0       3          13   16 NaN
# 1  0.2727  0.80        0.0       8          32   40 NaN
# 2  0.2727  0.80        0.0       5          27   32 NaN
# 3  0.2879  0.75        0.0       3          10   13 NaN
# 4  0.2879  0.75        0.0       0           1    1 NaN

# %% [markdown]
# **Treating missing values**

# %%
final_data_set.isnull()
# Out:
#      instant  dteday  season   mnth     hr  holiday  weekday  weathersit  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# ..       ...     ...     ...    ...    ...      ...      ...         ...
# 385    False   False   False  False  False    False    False       False
# 386    False   False   False  False  False    False    False       False
# 387    False   False   False  False  False    False    False       False
# 388    False   False   False  False  False    False    False       False
# 389    False   False   False  False  False    False    False       False
#
#       temp  atemp    hum  windspeed  casual  registered    cnt     yr
# ...

# %%
final_data_set.bfill()
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0          1 2011-01-01       1     1   0    False        6           1  0.24
# 1          2 2011-01-01       1     1   1    False        6           1  0.22
# 2          3 2011-01-01       1     1   2    False        6           1  0.22
# 3          4 2011-01-01       1     1   3    False        6           1  0.24
# 4          5 2011-01-01       1     1   4    False        6           1  0.24
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28       1     1  20    False        5           2  0.24
# 386      616 2011-01-28       1     1  21    False        5           2  0.22
# 387      617 2011-01-28       1     1  22    False        5           1  0.24
# 388      618 2011-01-28       1     1  23    False        5           1  0.24
# 389      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %%
final_data_set.dropna(axis =0, inplace=True)
final_data_set
# Out:
#      instant     dteday  season  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620 2011-01-29       1     1   1    False        6           1  0.22
# 1        621 2011-01-29       1     1   2    False        6           1  0.22
# 2        622 2011-01-29       1     1   3    False        6           1  0.20
# 3        623 2011-01-29       1     1   4    False        6           1  0.16
# 4        624 2011-01-29       1     1   6    False        6           1  0.16
# ..       ...        ...     ...   ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28       1     1  20    False        5           2  0.24
# 386      616 2011-01-28       1     1  21    False        5           2  0.22
# 387      617 2011-01-28       1     1  22    False        5           1  0.24
# 388      618 2011-01-28       1     1  23    False        5           1  0.24
# 389      619 2011-01-29       1     1   0    False        6           1  0.22
#
# ...

# %% [markdown]
# **To detecct Outliers**

# %%
final_data_set.describe()
# Out:
#            instant                         dteday  season        mnth  \
# count   390.000000                            390   390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0    1.800000
# min     611.000000            2011-01-28 00:00:00     1.0    1.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    2.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0    2.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0    2.000000
# max    1000.000000            2011-02-14 00:00:00     1.0    2.000000
# std     112.727548                            NaN     0.0    0.400514
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    11.687179    2.989744    1.484615    0.220000    0.230424    0.613769
# min      0.000000    0.000000    1.000000    0.060000    0.075800    0.210000
# ...

# %% [markdown]
# **Observations:**
#  - **Total Count :**
#    - The Q1 ranges from 1.000000 to 18.500000 i.e, The first 25 % points are reported in the range of 1 to 18.
#    - The Q2 ranges from 18.500000 to 52.000000 i.e, The second 25 % points are reported in the range of 18 to 52.
#    - The Q3 ranges from 52.000000 to 88.750000 i.e, The third 25 % points are reported in the range of 52 to 88.
#    - The Q4 range from 88.750000 to 243.000000 ii.e, The fourth 25% points are repotrted in the range of 88 to 243.
#    - The Inter-quartile range calculated for Overall Rating Q3 -Q1 = 88 - 18 = 70

# %%
plt.figure(figsize=[16,5])
plt.subplot(1,2,1)
sns.histplot(final_data_set['cnt'])

plt.subplot(1,2,2)
sns.histplot(final_data_set['registered'])
plt.show()

plt.subplot(1,2,2)
sns.histplot(final_data_set['casual'])
plt.show()

# %% [markdown]
# ## **Checking the Skewness and Correlation**

# %%
skewness_column1 = final_data_set['casual'].skew()
skewness_column2 = final_data_set['registered'].skew()

print("Skewness for Column1:", skewness_column1)
print("Skewness for Column2:", skewness_column2)
# Out:
# Skewness for Column1: 3.413724319400826
# Skewness for Column2: 1.1159118926924771

# %%
# Calculate correlation matrix for all columns
correlation_matrix = final_data_set.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#              instant    dteday  season      mnth        hr  holiday   weekday  \
# instant     1.000000  0.998153     NaN  0.692823 -0.018596      NaN  0.000053
# dteday      0.998153  1.000000     NaN  0.693970 -0.079014      NaN -0.001995
# season           NaN       NaN     NaN       NaN       NaN      NaN       NaN
# mnth        0.692823  0.693970     NaN  1.000000 -0.056458      NaN  0.093148
# hr         -0.018596 -0.079014     NaN -0.056458  1.000000      NaN  0.050662
# holiday          NaN       NaN     NaN       NaN       NaN      NaN       NaN
# weekday     0.000053 -0.001995     NaN  0.093148  0.050662      NaN  1.000000
# weathersit -0.220022 -0.215753     NaN  0.027074 -0.054857      NaN  0.052128
# temp        0.164053  0.147810     NaN  0.126446  0.278821      NaN -0.289220
# atemp       0.117704  0.105316     NaN  0.091299  0.225257      NaN -0.319828
# hum        -0.403658 -0.389363     NaN -0.125794 -0.211255      NaN  0.049960
# ...
